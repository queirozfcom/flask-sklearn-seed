# %%
import pandas as pd

# %%
df = pd.read_parquet("../data/raw/training_set.parquet")

# %%
df
# Out:
#                                         ids default  score_3     score_4  \
# 37031  211cc6dd-d9d5-168e-77c3-bde1d68bd57a   False    320.0   99.240818
# 62186  4a042336-efed-db81-9efc-99b4ed141d67   False    330.0   97.901421
# 42263  c1c48dfb-a0aa-6eaf-f963-8f2058e99f4f   False    420.0   99.384867
# 4942   93f72ae9-29e5-f757-040a-82f296fbd817   False    310.0  100.256491
# 44966  e2425642-2c89-6592-4bae-c7457ac9bfce   False    350.0   99.627717
# 73075  3d6a3dc6-e9a8-1148-7965-47bd4a125708    True    290.0  100.601591
# 4223   474905cf-4812-c703-6a5e-52f132179c66    None    450.0   98.868523
# 55375  a4cf4533-45dd-523f-5c3b-6c60926f8476   False    510.0  102.042732
# 14964  f298a213-e467-1c61-d3d8-6cb31c046268    True    260.0   95.695081
# 58417  707245bd-ec6d-60ae-baab-5b8c78083fc9   False    400.0   98.004895
# 71308  40687fb1-04b9-19bc-e347-573e4b3edc3d   False    440.0   99.230697
# 70281  2ba102a6-0c98-0f23-9ce3-d49e3d0b0d3f    True    430.0   96.251990
# ...
